# %% [markdown]
# # Logistic Regression - Defaulters Dataset

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("banking.csv")
print("Rows,Columns:",df.shape)
# Out:
# Rows,Columns: (41188, 21)

# %%
print(list(df.columns))
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y']

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
df = df[["y","age","job","education","default","marital","loan","poutcome"]]
df
# Out:
#        y  age            job            education  default   marital     loan  \
# 0      0   44    blue-collar             basic.4y  unknown   married       no
# 1      0   53     technician              unknown       no   married       no
# 2      1   28     management    university.degree       no    single       no
# 3      0   39       services          high.school       no   married       no
# 4      1   55        retired             basic.4y       no   married       no
# 5      0   30     management             basic.4y       no  divorced       no
# 6      0   37    blue-collar             basic.4y       no   married       no
# 7      0   39    blue-collar             basic.9y       no  divorced       no
# 8      1   36         admin.    university.degree       no   married       no
# 9      0   27    blue-collar             basic.4y       no    single       no
# 10     0   34      housemaid    university.degree       no    single       no
# 11     0   41     management    university.degree       no   married       no
# 12     1   55     management    university.degree       no   married       no
# 13     0   33       services          high.school       no  divorced       no
# 14     0   26         admin.          high.school       no   married      yes
# 15     0   52       services          high.school  unknown   married       no
# 16     1   35       services          high.school       no   married       no
# 17     1   27         admin.    university.degree       no    single       no
# 18     0   28    blue-collar             basic.9y  unknown   married       no
# 19     0   26     unemployed             basic.9y       no    single      yes
# 20     0   41     unemployed             basic.9y  unknown   married       no
# 21     0   35    blue-collar              unknown       no    single      yes
# 22     0   40         admin.    university.degree  unknown   married       no
# 23     0   32     technician  professional.course       no    single       no
# 24     0   41    blue-collar          high.school       no   married      yes
# 25     0   34   entrepreneur    university.degree       no    single       no
# 26     0   49     technician              unknown       no  divorced      yes
# 27     0   37         admin.          high.school       no   married       no
# 28     0   35    blue-collar             basic.6y  unknown   married       no
# 29     0   38    blue-collar             basic.4y  unknown    single       no
# ...   ..  ...            ...                  ...      ...       ...      ...
# 41158  0   30       services          high.school  unknown   married  unknown
# 41159  0   47         admin.          high.school  unknown  divorced       no
# 41160  0   57     management    university.degree  unknown  divorced      yes
# 41161  0   43    blue-collar          high.school  unknown   married       no
# 41162  0   43  self-employed          high.school  unknown   married       no
# 41163  0   22    blue-collar             basic.9y       no    single       no
# 41164  0   33     technician  professional.course       no    single       no
# 41165  0   56         admin.              unknown       no   married       no
# 41166  0   31         admin.              unknown       no   married       no
# 41167  0   30         admin.          high.school       no    single       no
# 41168  0   29    blue-collar             basic.9y  unknown    single       no
# 41169  0   46     technician             basic.9y       no   married       no
# 41170  0   32     technician    university.degree       no    single      yes
# 41171  0   42         admin.          high.school  unknown   married       no
# 41172  1   27    blue-collar             basic.9y  unknown    single       no
# 41173  0   39  self-employed          high.school       no   married       no
# 41174  0   49   entrepreneur    university.degree       no   married       no
# 41175  0   46    blue-collar             basic.4y  unknown   married       no
# 41176  0   30    blue-collar             basic.9y       no    single       no
# 41177  0   52  self-employed    university.degree  unknown    single       no
# 41178  1   35     technician          high.school       no   married       no
# 41179  0   29     technician             basic.9y       no    single       no
# 41180  0   44       services          high.school  unknown   married      yes
# 41181  0   39         admin.    university.degree       no   married       no
# 41182  0   24         admin.          high.school       no   married       no
# 41183  0   59        retired          high.school  unknown   married      yes
# 41184  0   31      housemaid             basic.4y  unknown   married       no
# 41185  0   42         admin.    university.degree  unknown    single      yes
# 41186  0   48     technician  professional.course       no   married      yes
# 41187  0   25        student          high.school       no    single       no
#
#           poutcome
# 0      nonexistent
# 1      nonexistent
# 2          success
# 3      nonexistent
# 4          success
# 5      nonexistent
# 6      nonexistent
# 7      nonexistent
# 8          success
# 9          failure
# 10     nonexistent
# 11     nonexistent
# 12     nonexistent
# 13     nonexistent
# 14     nonexistent
# 15     nonexistent
# 16     nonexistent
# 17     nonexistent
# 18     nonexistent
# 19     nonexistent
# 20         failure
# 21     nonexistent
# 22     nonexistent
# 23     nonexistent
# 24     nonexistent
# 25     nonexistent
# 26     nonexistent
# 27         success
# 28     nonexistent
# 29     nonexistent
# ...            ...
# 41158  nonexistent
# 41159  nonexistent
# 41160  nonexistent
# 41161  nonexistent
# 41162  nonexistent
# 41163  nonexistent
# 41164  nonexistent
# 41165  nonexistent
# 41166  nonexistent
# 41167  nonexistent
# 41168  nonexistent
# 41169  nonexistent
# 41170  nonexistent
# 41171  nonexistent
# 41172  nonexistent
# 41173  nonexistent
# 41174  nonexistent
# 41175  nonexistent
# 41176  nonexistent
# 41177  nonexistent
# 41178  nonexistent
# 41179  nonexistent
# 41180  nonexistent
# 41181  nonexistent
# 41182      failure
# 41183  nonexistent
# 41184  nonexistent
# 41185  nonexistent
# 41186  nonexistent
# 41187  nonexistent
#
# [41188 rows x 8 columns]

# %% [markdown]
# # Data Visualization
#
# It is always good practice to visualize your data to understand the data in order to fit the model using the best predictors.

# %%
plt.hist(df["y"])
plt.show()

# %%
sb.countplot(y="education",data = df)
plt.show()

# %%
sb.heatmap(df.corr())
plt.show()

# %% [markdown]
# # Data Selection

# %%
y = df[["y"]]
x = df.drop(["y"], axis = 1)

# %%
data = pd.get_dummies(x, columns =['job', 'marital', 'default',"education", 'loan', 'poutcome'])

# %%
data = data.drop(["loan_unknown","job_unknown","marital_unknown","education_unknown","default_unknown"], axis = 1)

# %%
x_train,x_test,y_train,y_test = train_test_split(data,y,test_size = 0.3)

# %% [markdown]
# # Model Fitting

# %%
classifier = LogisticRegression()
classifier.fit(x_train,y_train) # try solver= sgd,multi_class =  ovo
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(x_test)

# Remember: Logistic Regression predicts probability of class, not actual class
y_pred_prob = classifier.predict_proba(x_test)

# %%
print(y_pred_prob[:5])
# Out:
# [[ 0.91272279  0.08727721]
#  [ 0.91807545  0.08192455]
#  [ 0.8826894   0.1173106 ]
#  [ 0.86850667  0.13149333]
#  [ 0.881876    0.118124  ]]

# %%
print(y_pred[:5])
# Out:
# [0 0 0 0 0]

# %% [markdown]
# # Confusion Matrix
#
# A confusion matrix is an effective method to measure the accuracy of a classification problem. Below the upper left corner number to True Negatives (no. of non-defaulters correctly predicted), the upper right number refers to False Negative (predicted non-default but actuall default), the lower left corner is False Positive (predicted default, actualy non-default) and the lower right corner is True Positive (predicted default, actually default)

# %%
from sklearn.metrics import confusion_matrix 
confuse = confusion_matrix(y_test,y_pred)
print(confuse)

print("\nTN =",confuse[0][0])
print("FN =",confuse[0][1])
print("FP =",confuse[1][0])
print("TP =",confuse[1][1])
# Out:
# [[10801   146]
#  [ 1165   245]]
#
# TN = 10801
# FN = 146
# FP = 1165
# TP = 245

# %%
#overall accuracy
accuracy = (confuse[0][0] + confuse[1][1])/ len(y_test)
print("accuracy of classifier is:",accuracy)
#precision is a measure of positive predictions negative or ratio of tp/overal p
precision =  confuse[1][1]/(confuse[1][1]+confuse[0][1])
print("precision:",precision)
#recall is proportion all true positive samples.
recall = confuse[1][1]/(confuse[1][1]+confuse[1][0])
print("recall:",recall)
# Out:
# accuracy of classifier is: 0.893906287934
# precision: 0.626598465473
# recall: 0.173758865248

# %% [markdown]
# # Precision vs. Recall
# In simple terms, high precision means that an algorithm returned substantially more relevant results than irrelevant ones, while high recall means that an algorithm returned most of the relevant results.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.90      0.99      0.94     10947
#           1       0.63      0.17      0.27      1410
#
# avg / total       0.87      0.89      0.87     12357
